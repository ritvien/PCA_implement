# %% [markdown]
# # 8.1

# %% [markdown]
# * Mạnh

# %% [markdown]
# ## Giả thiết:

# %% [markdown]
# 👉 Ma trận ban đầu: X'
# 👉 $\Sigma $ : Ma trận hiệp phương sai
# 👉 Các cặp gt riêng - vt riêng của $\Sigma$: ($\lambda_1, e_1$), (...)

# %% [markdown]
# 👉 Thành phần chính Y:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Kết luận

# %% [markdown]
# 👉 $a_p = e_p$ thì:
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉 $Y_i$ và $Y_k$ với i khác k thì  $Y_i$ và $Y_k$ không tương quan với nhau (độc lập):
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8.2

# %% [markdown]
# * Mạnh

# %% [markdown]
# ## Giả thiết

# %% [markdown]
# 👉 Như **8.1**

# %% [markdown]
# 👉 $\sigma_i$ là phương sai của ma trận hiệp phương sai $\Sigma$ ban đầu

# %% [markdown]
# ## Kết luận

# %% [markdown]
# * Tổng phương sai của Y sau khi biến đổi (**như trên**), vẫn bằng tổng phương sai ban đầu của X

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Hoặc:
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8.3 Nói về lượng thông tin giữ lại ở k thành phần chính so với p thành phần ban đầu

# %% [markdown]
# * Hải

# %% [markdown]
# ## Giả thiết

# %% [markdown]
# 👉 $a'_k$: Là vecto đơn vị : $[0,...,1,...,0]$

# %% [markdown]
# 👉 $X_k = a'_k X$ : Là một vector chứa 1 giá trị thứ k, còn lại = 0

# %% [markdown]
# ## Kết luận

# %% [markdown]
# 👉 Hệ số tương quan giữa $Y_i$ và $X_k$ (thể hiện sự tương quan giữa thành phần chính thứ i và đặc trưng ban đầu thứ k) được tính theo công thức:
# $$\rho_{Y_i,X_k} = \frac{e_{ik}\sqrt{\lambda_i}}{\sigma_{kk}}$$

# %% [markdown]
# # 8.4

# %% [markdown]
# * Hoàng

# %% [markdown]
# ## Giả thiết

# %% [markdown]
# 👉 $ Z' = [Z_1,Z_2,...,Z_p]$ là các biến được chuẩn hóa

# %% [markdown]
# 👉 $ Z_p = \frac{X_p - \mu_p}{\sqrt{\sigma_{pp}}}$,  tổng quát: $Z = (V^{1/2})^{-1}(X-\mu)$

# %% [markdown]
# 👉 $Cov(Z) =$ **$\rho$**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Kết luận

# %% [markdown]
# 👉 Phương sai tổng thể của các **thành phần chính** vẫn bằng phương sai tổng thể của các **biến đã chuẩn hóa**
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉 Hệ số tương quan của thành phần chính thứ i so với biến chuẩn hóa thứ k được tính theo công thức:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Ma trận hiệp phương sai đặc biệt

# %% [markdown]
# * Thao

# %% [markdown]
# ## Ma trận đường chéo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉 Thì thành phần chính, chính là tổ hợp ban đầu:  $Y_i = $
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color: green; font-size: 24px;">&#10004;</span>
#  Visualize cho dễ hình dung

# %% [markdown]
# ## Trường hợp 2

# %% [markdown]
# * Ma trận hiệp phương sai:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Ma trận tương quan:
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉

# %%
<span style="color:red">&#10060;</span> : X

👉 👇


⚠️

<span style="color: green; font-size: 24px;">&#10004;</span>
: Dấu tích

&#128161; : bóng đèn

<font size =5> &#x1F9EE; Công thức 

<font size =5> &#x1F4DA; : Bài tập
   
<img src='link' style="width:500px;"/> : Chèn ảnh
    
<div style="margin-left: 200px;">: căn lề
    
<span style="color: red;"> Chữ_màu</span>
